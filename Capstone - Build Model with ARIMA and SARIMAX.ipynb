# %% [markdown]
# # Stock Price Prediction (Part 1 of 2)

# %% [markdown]
# **Problem Statement**
#
# The objective is to create a predictive model to forecast future stock closing prices.
#
# For the purpose of this presentation I will be showcasing the AMD stock ticker.

# %% [markdown]
# **Model Explored**
#
# |Models|Description|
# |---|---|
# |ARIMA|Autoregressive Integrated Moving Average|
# |SARIMAX|Seasonal AutoRegressive Integrated Moving Averages|

# %% [markdown]
# **Workflow Process**
# 1. Notebook 1 of 2 : ARIMA & SARIMAX : Data Collection
# 2. Notebook 1 of 2 : ARIMA & SARIMAX : General EDA
# 3. Notebook 1 of 2 : ARIMA & SARIMAX : Pre-Processing
# 4. Notebook 1 of 2 : ARIMA & SARIMAX : Modeling
# 5. Notebook 2 of 2 : GRU & LSTM : Data Collection
# 6. Notebook 2 of 2 : GRU & LSTM : General EDA
# 7. Notebook 2 of 2 : GRU & LSTM : Pre-Processing
# 7. Notebook 2 of 2 : GRU & LSTM : Modeling

# %% [markdown]
# # 0.0 Libraries Import

# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import impyute as impy

from math import sqrt
from pandas import Series
from numpy import isnan
from datetime import datetime
from datetime import timedelta
from time import time
from pandas.tseries.offsets import DateOffset

from pmdarima.arima import auto_arima
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import PowerTransformer
from sklearn import metrics
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.stattools import adfuller
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# # 1.0 Data Import

# %%
# from secrets2 import key

# %%
# df = pdr.get_data_tiingo('AMD', api_key=key)

# %%
# df.to_csv('AMD.csv')

# %%
df = pd.read_csv('AMD.csv')

# %%
df
# Out:
#      symbol                       date   close    high     low    open  \
# 0       AMD  2016-12-19 00:00:00+00:00  10.950  11.000  10.520  10.810
# 1       AMD  2016-12-20 00:00:00+00:00  11.510  11.510  11.150  11.190
# 2       AMD  2016-12-21 00:00:00+00:00  11.470  11.720  11.310  11.610
# 3       AMD  2016-12-22 00:00:00+00:00  11.600  11.750  11.470  11.650
# 4       AMD  2016-12-23 00:00:00+00:00  11.580  11.600  11.260  11.300
# ...     ...                        ...     ...     ...     ...     ...
# 1253    AMD  2021-12-10 00:00:00+00:00 138.550 141.365 135.820 141.290
# 1254    AMD  2021-12-13 00:00:00+00:00 133.800 139.400 133.415 138.250
# 1255    AMD  2021-12-14 00:00:00+00:00 135.600 137.240 130.600 131.670
# 1256    AMD  2021-12-15 00:00:00+00:00 146.500 146.690 133.810 135.110
# 1257    AMD  2021-12-16 00:00:00+00:00 138.640 147.930 137.020 147.000
#
#         volume  adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# 0     46085840    10.950   11.000  10.520   10.810   46085840    0.000
# 1     59314159    11.510   11.510  11.150   11.190   59314159    0.000
# 2     44814131    11.470   11.720  11.310   11.610   44814131    0.000
# 3     36450756    11.600   11.750  11.470   11.650   36450756    0.000
# 4     32288235    11.580   11.600  11.260   11.300   32288235    0.000
# ...        ...       ...      ...     ...      ...        ...      ...
# 1253  42224275   138.550  141.365 135.820  141.290   42224275    0.000
# 1254  42173963   133.800  139.400 133.415  138.250   42173963    0.000
# 1255  50754642   135.600  137.240 130.600  131.670   50754642    0.000
# 1256  72425783   146.500  146.690 133.810  135.110   72425783    0.000
# 1257  63369550   138.640  147.930 137.020  147.000   63369550    0.000
#
#       splitFactor
# 0           1.000
# 1           1.000
# 2           1.000
# 3           1.000
# 4           1.000
# ...           ...
# 1253        1.000
# 1254        1.000
# 1255        1.000
# 1256        1.000
# 1257        1.000
#
# [1258 rows x 14 columns]

# %% [markdown]
# # 2.0 General EDA
# ___
#
# * 2.1 Pre-processing of dates and prefered columns
# * 2.2 Time Series Plot
# * 2.3 Trend & Seasonality

# %% [markdown]
# ### 2.1 Pre-processing of Dates and Prefered Columns
# ___

# %%
df['date'] = df['date'].map(lambda x : x[:-14])

# %%
# Add Year, Month, Week and Day of Week features
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].apply(lambda x: x.year)
df['month'] = df['date'].apply(lambda x: x.month)
df['week'] = df['date'].apply(lambda x: x.week)
df['dayofweek'] = df['date'].apply(lambda x: x.dayofweek)

# %%
df.set_index('date', inplace=True)

# %%
df1 = pd.DataFrame(df[['close','volume','year','month','week','dayofweek']].groupby(df.index).sum())

# %% [markdown]
# ### 2.2 Time Series Plot
# ___

# %%
plt.figure(figsize=(16,9))
plt.title('AMD Closing Prices', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.plot(df1['close']);

# %%
x = df1.index
y1 = df1['close'].values

# Plot
fig, ax = plt.subplots(1, 1, figsize=(16,5), dpi= 120)
plt.fill_between(x, y1=y1, y2=-y1, alpha=0.5, linewidth=2, color='seagreen')
plt.ylim(-200, 200)
plt.title('Closing Price of AMD (Two Side View)', fontsize=16)
plt.hlines(y=0, xmin=np.min(df1.index), xmax=np.max(df1.index), linewidth=.5)
plt.show()

# %% [markdown]
# ### 2.3 Trend & Seasonality
# ___

# %%
# Prepare data
years = df['year'].unique()

# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='year', y='close', data=df, ax=axes[0])
sns.boxplot(x='month', y='close', data=df.loc[~df.year.isin([2019, 2021]), :])

# Set Title
axes[0].set_title('Year-wise Box Plot\n(The Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %%
result = seasonal_decompose(df1['close'], model='additive', freq = 24)

# %%
fig = plt.figure(figsize=(16,9))
plt.title('AMD Price Trend', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.plot(result.trend);

# %% [markdown]
# # 3.0 Pre-Processing
# ___
#
# * 3.1 AdFuller Test
# * 3.2 Autocorrelation and Partial Autocorrelation Test

# %% [markdown]
# ### 3.1 AdFuller Test
# ___

# %%
test_result = adfuller(df['close'])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['close'])
# Out:
# ADF Test Statistic : 1.0619373855296097
# p-value : 0.9948783170701314
# #Lags Used : 19
# Number of Observations Used : 1238
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df1['close_first_difference'] = df1['close'] - df1['close'].shift(1)

# %%
## Again test dickey fuller test
adfuller_test(df1['close_first_difference'].dropna())
# Out:
# ADF Test Statistic : -7.713292838536606
# p-value : 1.2472697523563291e-11
# #Lags Used : 18
# Number of Observations Used : 1238
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df1['seasonal_first_difference']=df1['close']-df1['close'].shift(24)

# %%
## Again test dickey fuller test
adfuller_test(df1['seasonal_first_difference'].dropna())
# Out:
# ADF Test Statistic : -8.920645708642992
# p-value : 1.0433701326082572e-14
# #Lags Used : 23
# Number of Observations Used : 1210
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
plt.figure(figsize=(16,9))
plt.title('Seasonal First Differencing', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
df1['seasonal_first_difference'].plot();

# %%
plt.figure(figsize=(16,9))
plt.title('Close First Differencing', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
df1['close_first_difference'].plot();

# %%
# histogram plot
fig = plt.figure(figsize=(16,9))
plt.title('Seasonal First Differencing', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
df1['seasonal_first_difference'].hist();

# %%
# histogram plot
fig = plt.figure(figsize=(16,9))
plt.title('Close First Differencing', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
df1['close_first_difference'].hist();

# %% [markdown]
# ### 3.2 Autocorrelation and Partial Autocorrelation Test
# ___

# %%
fig = plt.figure(figsize=(16,9))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df1['seasonal_first_difference'].iloc[24:],lags=50,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df1['seasonal_first_difference'].iloc[24:],lags=50,ax=ax2)

# %%
fig = plt.figure(figsize=(16,9))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df1['close_first_difference'].iloc[1:],lags=50,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df1['close_first_difference'].iloc[1:],lags=50,ax=ax2)

# %% [markdown]
# # 4.0 Modeling
# ___
#
# * 4.1 Split Data (80% Train -20% Split)
# * 4.2 Instantiate ARIMA Model
# * 4.3 Plot ARIMA Predictions
# * 4.4 Evaluate ARIMA Predictions
# * 4.5 Split Data (80% Train -20% Split)
# * 4.6 Instantiate SARIMAX Model
# * 4.7 Plot SARIMAX Predictions
# * 4.8 Evaluate SARIMAX Predictions

# %% [markdown]
# ### 4.1 Split Data (80% Train -20% Split)
# ___

# %%
# Create train-test split.
y_train, y_test = train_test_split(df1, test_size=.2, shuffle=False)

# %% [markdown]
# ### 4.2 Instantiate ARIMA Model
# ___

# %%
# Instantiate an ARIMA model on training data.

ar1 = ARIMA(endog = y_train['close'],
            order = (1, 1, 1)) # (p, d, q)

# Fit model.
model = ar1.fit()

# Generate predictions based on test set.
# Start at time period 1005 and end at 1256.
preds = model.predict(start=1005, end=1256)

# %% [markdown]
# ### 4.3 Plot ARIMA Predictions
# ___

# %%
y_test['preds'] = preds.values

# %%
# Plot data.
plt.figure(figsize=(16,9))
plt.plot(y_test['close'], color = 'orange', label = 'Test')
plt.plot(y_test['preds'], color = 'green', label = 'Prediction')
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.title(label = 'ARIMA Predictions', fontsize=16)
plt. legend(loc='best')
plt.show();

# %% [markdown]
# ### 4.4 Evaluate ARIMA Predictions
# ___

# %%
def mape(actual, pred): 
    actual, pred = np.array(y_test['close']), np.array(y_test['preds'])
    return np.mean(np.abs((y_test['close'] - y_test['preds']) / actual)) * 100

# %%
result = mape(y_test['close'],y_test['preds'])

# %%
print(f'The average difference between the predicted value and the actual value is {result}%')
# Out:
# The average difference between the predicted value and the actual value is 16.03065650750745%

# %% [markdown]
# ### 4.5 Split Data (80% Train -20% Split)
# ___

# %%
# Create train-test split.
y_train, y_test = train_test_split(df1, test_size=.2, shuffle=False)

# %% [markdown]
# ### 4.6 Instantiate SARIMAX Model
# ___

# %%
# Fit and visualize a SARIMAX(1, 1, 1) x (1, 1, 1, 24) model.

sarima = SARIMAX(endog = y_train['close'].iloc[1:],
                 order = (1, 1, 1),              # (p, d, q)
                 seasonal_order = (1, 1, 1, 40), # (P, D, Q, S)
                 exog = y_train['close_first_difference'].iloc[1:])

# Fit SARIMA model.
model = sarima.fit()

# Generate predictions based on test set.
# Start at time period 1005 and end at 1255.
preds = model.predict(start=1005, end=1255, exog=y_test[['close_first_difference']].iloc[1:])

# %%
y_test.drop(index=y_test.index[0], 
        axis=0, 
        inplace=True)

# %% [markdown]
# ### 4.7 Plot SARIMAX Predictions
# ___

# %%
y_test['preds'] = preds.values

# %%
# Plot data.
plt.figure(figsize=(16,9))
plt.plot(y_test['close'], color = 'orange', label = 'Test')
plt.plot(y_test['preds'], color = 'green', label = 'Prediction')
plt.ylabel('Price', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.title(label = 'SARIMAX Predictions', fontsize=16)
plt. legend(loc='upper left')
plt.show();

# %% [markdown]
# ### 4.8 Evaluate SARIMAX Predictions
# ___

# %%
result = mape(y_test['close'],y_test['preds'])

# %%
print(f'The average difference between the predicted value and the actual value is {result}%')
# Out:
# The average difference between the predicted value and the actual value is 16.972347297212657%
